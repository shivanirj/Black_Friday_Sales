# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('BlackFriday.csv')

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# # Analysing Columns

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df['Purchase'].sum()/len(df['Purchase'])
# Out:
# 9333.859852635065

# %%
for column in df.columns:
    print(column,':',df[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %% [markdown]
# # Analysing Gender

# %%
df.groupby('Gender').size()
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %%
df.groupby('Gender').size().plot(kind='pie',autopct='%.1f',figsize=(6,6))
# Out:
# <Axes: >

# %%
df.groupby('Gender').size().plot(kind='bar',figsize=(6,6))
# Out:
# <Axes: xlabel='Gender'>

# %%
df.groupby('Gender')['Purchase'].sum().plot(kind='bar',figsize=(6,6))
# Out:
# <Axes: xlabel='Gender'>

# %%
df.groupby('Gender')['Purchase'].sum().plot(kind='pie',autopct='%.1f',figsize=(6,6))
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Gender')['Purchase'].mean().plot(kind='pie',autopct='%.1f',figsize=(6,6))
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# # Analysing Age and Marital Status

# %%
df.head(5)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby('Age').size().plot(kind='bar',title='Purchase Distribution by Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %%
lst = []
for i in df['Age'].unique():
    lst.append([i,df[df['Age']==i]['Product_ID'].nunique()])
data = pd.DataFrame(lst,columns=['Age','Products'])

# %%
data
# Out:
#      Age  Products
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
sns.barplot(data=data,x='Age',y='Products')
# Out:
# <Axes: xlabel='Age', ylabel='Products'>

# %%
df[df['Age']==i]['Product_ID'].nunique()
# Out:
# 3213

# %%
df.groupby('Age')['Purchase'].sum().plot(kind='bar',title='Amount Distribution by Age')
# Out:
# <Axes: title={'center': 'Amount Distribution by Age'}, xlabel='Age'>

# %%
df.groupby('Age')['Purchase'].mean().plot(kind='bar',title='Average Price Distribution by Age')
# Out:
# <Axes: title={'center': 'Average Price Distribution by Age'}, xlabel='Age'>

# %%
df.groupby('Age')['Purchase'].mean().plot(kind='pie',autopct='%.1f',title='Average Price Distribution by Age')
# Out:
# <Axes: title={'center': 'Average Price Distribution by Age'}, ylabel='Purchase'>

# %%
df.groupby('Marital_Status').size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %% [markdown]
# # Multi Column Analysis

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200

# %%
sns.countplot(data=df,x='Age',hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df.dtypes
df['Marital_Status'] = df['Marital_Status'].astype(str)

# %%
sns.countplot(data=df,x='Gender',hue='Marital_Status')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df,x='Marital_Status',hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x=df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
sns.countplot(data=df,x='City_Category',hue='Age')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(data=df,x='Age',hue='City_Category')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(data=df,x='City_Category',hue='Gender')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category')['Purchase'].sum().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('City_Category')['Purchase'].mean().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
sns.countplot(data=df,x='City_Category',hue='Marital_Status')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %% [markdown]
# # Occupation and Product Analysis

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years Marital_Status  Product_Category_1  Purchase
# 0                          2              0                   3      8370
# 1                          2              0                   1     15200

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=df,x='Stay_In_Current_City_Years',hue='Age')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=df,x='Stay_In_Current_City_Years',hue='Gender')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=df,x='Stay_In_Current_City_Years',hue='Marital_Status')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=df,x='Stay_In_Current_City_Years',hue='City_Category')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=df,x='City_Category',hue='Age')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x=df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
# Purchasing More
df.groupby('Occupation').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
# Spending More
df.groupby('Occupation')['Purchase'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
# Average(Buying most expensive no of product that is 17)
df.groupby('Occupation')['Purchase'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')['Purchase'].mean().sort_values(ascending=False)
# Out:
# Occupation
# 17    9906.378997
# 12    9883.052460
# 15    9866.239925
# 8     9576.508530
# 14    9568.536426
# 7     9502.175276
# 16    9457.133118
# 13    9424.449391
# 5     9388.848978
# 6     9336.378620
# 11    9299.467190
# 4     9279.026742
# 3     9238.077277
# 18    9233.671418
# 0     9186.946726
# 10    9052.836410
# 2     9025.938982
# 1     9017.703095
# 20    8881.099514
# 19    8754.249162
# 9     8714.335934
# Name: Purchase, dtype: float64

# %%
sns.countplot(data=df,x='Occupation',hue='Marital_Status')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(data=df,x='Occupation',hue='Gender')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# ### How many unique product id are there , people buying from the occupation?

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years Marital_Status  Product_Category_1  Purchase
# 0                          2              0                   3      8370
# 1                          2              0                   1     15200

# %%
for i in df['Occupation'].unique():
    print(i,len(df[df['Occupation'] == i]['Product_ID'].unique()))
# Out:
# 10 2110
# 16 2863
# 15 2168
# 7 3070
# 20 3147
# 9 1820
# 1 3020
# 12 2664
# 17 2831
# 0 3243
# 3 2657
# 4 3174
# 11 2235
# 8 1026
# 19 2303
# 2 2892
# 18 2047
# 5 2344
# 14 2680
# 13 1946
# 6 2724

# %%
len(df[df['Occupation'] == i]['Product_ID'].unique())
# Out:
# 2724

# %%
df.groupby('Occupation')['Product_ID'].nunique()
# Out:
# Occupation
# 0     3243
# 1     3020
# 2     2892
# 3     2657
# 4     3174
# 5     2344
# 6     2724
# 7     3070
# 8     1026
# 9     1820
# 10    2110
# 11    2235
# 12    2664
# 13    1946
# 14    2680
# 15    2168
# 16    2863
# 17    2831
# 18    2047
# 19    2303
# 20    3147
# Name: Product_ID, dtype: int64

# %%
df.groupby('Occupation')['Product_ID'].nunique().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')['Product_ID'].nunique().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')['Purchase'].sum().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
# Expensive Product
df.groupby('Product_Category_1')['Purchase'].mean().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
# People Spend most money
df.groupby('Product_ID')['Purchase'].sum().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
# Most Selling Products
df.groupby('Product_ID')['Purchase'].size().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
# Most Expensive Product
df.groupby('Product_ID')['Purchase'].mean().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
sns.countplot(data=df,x='Product_Category_1',hue='Gender')
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(data=df,x='Product_Category_1',hue='Marital_Status')
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# # Combining Gender and Marital Status

# %%
l = []
for i in range(len(df)):
    l.append(df['Gender'][i] + df['Marital_Status'][i])
df['MaritalGender'] = l

# %%
df.head(5)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years Marital_Status  Product_Category_1  Purchase  \
# 0                          2              0                   3      8370
# 1                          2              0                   1     15200
# 2                          2              0                  12      1422
# 3                          2              0                  12      1057
# 4                         4+              0                   8      7969
#
#   MaritalGender
# 0            F0
# 1            F0
# 2            F0
# 3            F0
# 4            M0

# %%
sns.countplot(x=df['MaritalGender'])
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>

# %%
sns.countplot(data=df,x='Age',hue='MaritalGender')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(data=df,x='Product_Category_1',hue='MaritalGender')
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(data=df,x='Stay_In_Current_City_Years',hue='MaritalGender')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=df,x='City_Category',hue='MaritalGender')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>
